# %%
import math
import random
def eval_fun(x1, x2):
    return 100 * (x2 - x1**2)**2 + (1 - x1)**2

# %%
def Teaching_Learning_Based_Optimization(eval_fun, n_variables, population_size, bounds, g_max, optimization_type):
    low, high = bounds[0], bounds[1]
    population = [[random.uniform(low, high) for _ in range(n_variables)] for _ in range(population_size)]
    fitness = [eval_fun(*ind) for ind in population]
    best_fitness = min(fitness) if optimization_type == 'min' else max(fitness)
    best_index = fitness.index(best_fitness)
    best_solution = population[best_index].copy()
    print(f"\nInitial Best ({optimization_type}): {best_solution} with fitness {best_fitness:.6f}")
    for gen in range(g_max):
        print(f"\n Generation {gen + 1} ")
        # Compute mean of population
        mean_pop = [sum(population[i][j] for i in range(population_size)) / population_size
                    for j in range(n_variables)]
        # TEACHER PHASE
        teacher_fitness = eval_fun(*best_solution)
        T = random.randint(1, 2)
        print(f"Teaching factor T = {T}")
        print(f"Population mean: {mean_pop}")
        new_population = [ind.copy() for ind in population] 
        for i in range(population_size):
            r = [random.random() for _ in range(n_variables)]
            diff_mean = [best_solution[j] - T * mean_pop[j] for j in range(n_variables)]
            new_ind = [population[i][j] + r[j] * diff_mean[j] for j in range(n_variables)]
            new_ind = [max(low, min(high, val)) for val in new_ind]
            new_f = eval_fun(*new_ind)
            if (optimization_type == 'min' and new_f < fitness[i]) or \
               (optimization_type == 'max' and new_f > fitness[i]):
                new_population[i] = new_ind
                fitness[i] = new_f  
        population = new_population  
        current_best_f = min(fitness) if optimization_type == 'min' else max(fitness)
        if (optimization_type == 'min' and current_best_f < best_fitness) or \
           (optimization_type == 'max' and current_best_f > best_fitness):
            best_fitness = current_best_f
            best_index = fitness.index(best_fitness)
            best_solution = population[best_index].copy()
        print(f"After Teacher - Best: {best_solution} ({best_fitness:.6f})")
        # LEARNER PHASE
        for i in range(population_size):
            j = random.randint(0, population_size - 1)
            while j == i:
                j = random.randint(0, population_size - 1)
            r = [random.random() for _ in range(n_variables)]
            if (optimization_type == 'min' and fitness[i] < fitness[j]) or \
               (optimization_type == 'max' and fitness[i] > fitness[j]):
                new_ind = [population[i][k] + r[k] * (population[i][k] - population[j][k])
                          for k in range(n_variables)]
            else:
                new_ind = [population[i][k] + r[k] * (population[j][k] - population[i][k])
                          for k in range(n_variables)]
            new_ind = [max(low, min(high, val)) for val in new_ind]
            new_f = eval_fun(*new_ind)
            if (optimization_type == 'min' and new_f < fitness[i]) or \
               (optimization_type == 'max' and new_f > fitness[i]):
                population[i] = new_ind
                fitness[i] = new_f
        current_best_f = min(fitness) if optimization_type == 'min' else max(fitness)
        if (optimization_type == 'min' and current_best_f < best_fitness) or \
           (optimization_type == 'max' and current_best_f > best_fitness):
            best_fitness = current_best_f
            best_index = fitness.index(best_fitness)
            best_solution = population[best_index].copy()
        print(f"After Learner - Best: {best_solution} ({best_fitness:.6f})")
        # for ii, ind in enumerate(population):
            # print(f"  {ii}: {ind} (f={fitness[ii]:.6f})")

    print("\n Final Result ")
    print(f"Best solution: {best_solution}")
    print(f"Best fitness: {best_fitness:.6f}")
    return best_solution, best_fitness

Teaching_Learning_Based_Optimization(eval_fun, 2, 200, [-5, 10], 100, 'min')
# Out:
# Initial Best (min): [1.614160377757086, 2.527961471739906] with fitness 0.978628
#
#  Generation 1
# Teaching factor T = 1
# Population mean: [2.266016184317198, 2.938427359912487]
# After Teacher - Best: [1.5511168736988374, 2.3631073716147775] (0.487395)
# After Learner - Best: [1.2477595476264438, 1.5806102121373211] (0.117584)
# Population after Gen 1:
#
#  Generation 2
# Teaching factor T = 1
# Population mean: [0.9012674189962927, 3.214418688656932]
# After Teacher - Best: [1.2477595476264438, 1.5806102121373211] (0.117584)
# After Learner - Best: [0.7233168985517116, 0.517451847167996] (0.079843)
# Population after Gen 2:
#
#  Generation 3
# Teaching factor T = 2
# Population mean: [0.5768988687765257, 3.075878834300545]
# After Teacher - Best: [0.7233168985517116, 0.517451847167996] (0.079843)
# After Learner - Best: [0.7306712684164189, 0.5299984143481102] (0.074045)
# Population after Gen 3:
#
#  Generation 4
# Teaching factor T = 2
# Population mean: [0.3149087042192116, 2.6022240736120055]
# After Teacher - Best: [0.7306712684164189, 0.5299984143481102] (0.074045)
# After Learner - Best: [0.7306712684164189, 0.5299984143481102] (0.074045)
# Population after Gen 4:
#
#  Generation 5
# Teaching factor T = 2
# Population mean: [0.24646789016669068, 2.4439909303764877]
# After Teacher - Best: [0.7306712684164189, 0.5299984143481102] (0.074045)
# After Learner - Best: [0.7306712684164189, 0.5299984143481102] (0.074045)
# Population after Gen 5:
#
#  Generation 6
# Teaching factor T = 2
# Population mean: [0.09267754786115517, 2.5308971970431773]
# After Teacher - Best: [0.7306712684164189, 0.5299984143481102] (0.074045)
# After Learner - Best: [0.9952473816167167, 0.9713140215091963] (0.036899)
# Population after Gen 6:
#
#  Generation 7
# Teaching factor T = 1
# Population mean: [0.12035554929390635, 2.3528794781836346]
# After Teacher - Best: [0.9952473816167167, 0.9713140215091963] (0.036899)
# After Learner - Best: [0.9952473816167167, 0.9713140215091963] (0.036899)
# Population after Gen 7:
#
#  Generation 8
# Teaching factor T = 2
# Population mean: [0.2227874239849304, 2.280421462604375]
# After Teacher - Best: [0.9952473816167167, 0.9713140215091963] (0.036899)
# After Learner - Best: [0.9952473816167167, 0.9713140215091963] (0.036899)
# Population after Gen 8:
#
#  Generation 9
# Teaching factor T = 1
# Population mean: [0.22934922722227835, 2.214906581029197]
# After Teacher - Best: [0.9952473816167167, 0.9713140215091963] (0.036899)
# After Learner - Best: [1.0228892612440394, 1.0409479425523869] (0.003391)
# Population after Gen 9:
#
#  Generation 10
# Teaching factor T = 2
# Population mean: [0.265102161112973, 2.107437825757558]
# After Teacher - Best: [1.0228892612440394, 1.0409479425523869] (0.003391)
# After Learner - Best: [1.0228892612440394, 1.0409479425523869] (0.003391)
# Population after Gen 10:
#
#  Generation 11
# Teaching factor T = 2
# Population mean: [0.31999505204004064, 2.021719974783652]
# After Teacher - Best: [1.0228892612440394, 1.0409479425523869] (0.003391)
# After Learner - Best: [0.9914498542682746, 0.9875945971138387] (0.002209)
# Population after Gen 11:
#
#  Generation 12
# Teaching factor T = 2
# Population mean: [0.3430173898358833, 1.9536155565031792]
# After Teacher - Best: [0.9914498542682746, 0.9875945971138387] (0.002209)
# After Learner - Best: [0.9914498542682746, 0.9875945971138387] (0.002209)
# Population after Gen 12:
#
#  Generation 13
# Teaching factor T = 2
# Population mean: [0.3415827455607069, 1.8984259133699002]
# After Teacher - Best: [0.9914498542682746, 0.9875945971138387] (0.002209)
# After Learner - Best: [0.9914498542682746, 0.9875945971138387] (0.002209)
# Population after Gen 13:
#
#  Generation 14
# Teaching factor T = 2
# Population mean: [0.3536868058367583, 1.8372355193030727]
# After Teacher - Best: [0.9914498542682746, 0.9875945971138387] (0.002209)
# After Learner - Best: [0.9914498542682746, 0.9875945971138387] (0.002209)
# Population after Gen 14:
#
#  Generation 15
# Teaching factor T = 2
# Population mean: [0.3852291441148108, 1.7639465682529891]
# After Teacher - Best: [0.9914498542682746, 0.9875945971138387] (0.002209)
# After Learner - Best: [0.9914498542682746, 0.9875945971138387] (0.002209)
# Population after Gen 15:
#
#  Generation 16
# Teaching factor T = 1
# Population mean: [0.3977824051886724, 1.7429344838212755]
# After Teacher - Best: [0.9914498542682746, 0.9875945971138387] (0.002209)
# After Learner - Best: [0.9914498542682746, 0.9875945971138387] (0.002209)
# Population after Gen 16:
#
#  Generation 17
# Teaching factor T = 2
# Population mean: [0.4308345924455535, 1.721989569295889]
# After Teacher - Best: [0.9914498542682746, 0.9875945971138387] (0.002209)
# After Learner - Best: [0.9914498542682746, 0.9875945971138387] (0.002209)
# Population after Gen 17:
#
#  Generation 18
# Teaching factor T = 1
# Population mean: [0.4467384660304176, 1.6880807756446483]
# After Teacher - Best: [0.9914498542682746, 0.9875945971138387] (0.002209)
# After Learner - Best: [0.9914498542682746, 0.9875945971138387] (0.002209)
# Population after Gen 18:
#
#  Generation 19
# Teaching factor T = 2
# Population mean: [0.4684344412400451, 1.6157284728544872]
# After Teacher - Best: [0.9914498542682746, 0.9875945971138387] (0.002209)
# After Learner - Best: [0.9914498542682746, 0.9875945971138387] (0.002209)
# Population after Gen 19:
#
#  Generation 20
# Teaching factor T = 1
# Population mean: [0.47915227690429674, 1.5773467221868203]
# After Teacher - Best: [0.9914498542682746, 0.9875945971138387] (0.002209)
# After Learner - Best: [0.9914498542682746, 0.9875945971138387] (0.002209)
# Population after Gen 20:
#
#  Generation 21
# Teaching factor T = 2
# Population mean: [0.5025368369766556, 1.516394840160962]
# After Teacher - Best: [0.9914498542682746, 0.9875945971138387] (0.002209)
# After Learner - Best: [0.9914498542682746, 0.9875945971138387] (0.002209)
# Population after Gen 21:
#
#  Generation 22
# Teaching factor T = 1
# Population mean: [0.5147143770155369, 1.5083367509956371]
# After Teacher - Best: [0.9914498542682746, 0.9875945971138387] (0.002209)
# After Learner - Best: [0.9914498542682746, 0.9875945971138387] (0.002209)
# Population after Gen 22:
#
#  Generation 23
# Teaching factor T = 1
# Population mean: [0.5366494202605295, 1.4939629227425502]
# After Teacher - Best: [0.9914498542682746, 0.9875945971138387] (0.002209)
# After Learner - Best: [0.9914498542682746, 0.9875945971138387] (0.002209)
# Population after Gen 23:
#
#  Generation 24
# Teaching factor T = 2
# Population mean: [0.5529305904461144, 1.4812474023628797]
# After Teacher - Best: [0.9914498542682746, 0.9875945971138387] (0.002209)
# After Learner - Best: [0.9914498542682746, 0.9875945971138387] (0.002209)
# Population after Gen 24:
#
#  Generation 25
# Teaching factor T = 1
# Population mean: [0.5542903963842217, 1.461777907366955]
# After Teacher - Best: [0.9914498542682746, 0.9875945971138387] (0.002209)
# After Learner - Best: [1.0035127426102664, 1.0043734853434512] (0.000722)
# Population after Gen 25:
#
#  Generation 26
# Teaching factor T = 2
# Population mean: [0.5679340232886878, 1.4298830422268411]
# After Teacher - Best: [1.0035127426102664, 1.0043734853434512] (0.000722)
# After Learner - Best: [1.0035127426102664, 1.0043734853434512] (0.000722)
# Population after Gen 26:
#
#  Generation 27
# Teaching factor T = 1
# Population mean: [0.5859510922295483, 1.4304072694209509]
# After Teacher - Best: [1.0035127426102664, 1.0043734853434512] (0.000722)
# After Learner - Best: [1.0035127426102664, 1.0043734853434512] (0.000722)
# Population after Gen 27:
#
#  Generation 28
# Teaching factor T = 1
# Population mean: [0.6070632384591965, 1.421708689158512]
# After Teacher - Best: [1.0035127426102664, 1.0043734853434512] (0.000722)
# After Learner - Best: [1.0035127426102664, 1.0043734853434512] (0.000722)
# Population after Gen 28:
#
#  Generation 29
# Teaching factor T = 1
# Population mean: [0.6142206900079834, 1.3561468759911934]
# After Teacher - Best: [1.0035127426102664, 1.0043734853434512] (0.000722)
# After Learner - Best: [1.0035127426102664, 1.0043734853434512] (0.000722)
# Population after Gen 29:
#
#  Generation 30
# Teaching factor T = 2
# Population mean: [0.6237889783090206, 1.350418801091938]
# After Teacher - Best: [1.0035127426102664, 1.0043734853434512] (0.000722)
# After Learner - Best: [1.0035127426102664, 1.0043734853434512] (0.000722)
# Population after Gen 30:
#
#  Generation 31
# Teaching factor T = 2
# Population mean: [0.6302362506391579, 1.3171581278409759]
# After Teacher - Best: [1.0035127426102664, 1.0043734853434512] (0.000722)
# After Learner - Best: [1.0035127426102664, 1.0043734853434512] (0.000722)
# Population after Gen 31:
#
#  Generation 32
# Teaching factor T = 2
# Population mean: [0.6385355380827046, 1.3126919045559478]
# After Teacher - Best: [1.0035127426102664, 1.0043734853434512] (0.000722)
# After Learner - Best: [1.0035127426102664, 1.0043734853434512] (0.000722)
# Population after Gen 32:
#
#  Generation 33
# Teaching factor T = 2
# Population mean: [0.6402324483197261, 1.313699564097609]
# After Teacher - Best: [1.0035127426102664, 1.0043734853434512] (0.000722)
# After Learner - Best: [1.0035127426102664, 1.0043734853434512] (0.000722)
# Population after Gen 33:
#
#  Generation 34
# Teaching factor T = 2
# Population mean: [0.6563310605370227, 1.2958956725673998]
# After Teacher - Best: [1.0035127426102664, 1.0043734853434512] (0.000722)
# After Learner - Best: [1.0035127426102664, 1.0043734853434512] (0.000722)
# Population after Gen 34:
#
#  Generation 35
# Teaching factor T = 2
# Population mean: [0.6577953655046166, 1.2942326037921625]
# After Teacher - Best: [1.0035127426102664, 1.0043734853434512] (0.000722)
# After Learner - Best: [1.0035127426102664, 1.0043734853434512] (0.000722)
# Population after Gen 35:
#
#  Generation 36
# Teaching factor T = 1
# Population mean: [0.661213728130457, 1.2780624024254263]
# After Teacher - Best: [1.0035127426102664, 1.0043734853434512] (0.000722)
# After Learner - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# Population after Gen 36:
#
#  Generation 37
# Teaching factor T = 1
# Population mean: [0.666685171856076, 1.2802124836200337]
# After Teacher - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# After Learner - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# Population after Gen 37:
#
#  Generation 38
# Teaching factor T = 1
# Population mean: [0.6761846885509131, 1.2854931066819868]
# After Teacher - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# After Learner - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# Population after Gen 38:
#
#  Generation 39
# Teaching factor T = 2
# Population mean: [0.6895302354818312, 1.2902466915286899]
# After Teacher - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# After Learner - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# Population after Gen 39:
#
#  Generation 40
# Teaching factor T = 1
# Population mean: [0.6921292933609726, 1.2523351242146294]
# After Teacher - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# After Learner - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# Population after Gen 40:
#
#  Generation 41
# Teaching factor T = 1
# Population mean: [0.7026910108839205, 1.2172483419407765]
# After Teacher - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# After Learner - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# Population after Gen 41:
#
#  Generation 42
# Teaching factor T = 2
# Population mean: [0.7082569659853758, 1.1990597038389874]
# After Teacher - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# After Learner - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# Population after Gen 42:
#
#  Generation 43
# Teaching factor T = 2
# Population mean: [0.7114808478750141, 1.1901045181445555]
# After Teacher - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# After Learner - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# Population after Gen 43:
#
#  Generation 44
# Teaching factor T = 1
# Population mean: [0.7240358454105171, 1.1705251717116523]
# After Teacher - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# After Learner - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# Population after Gen 44:
#
#  Generation 45
# Teaching factor T = 2
# Population mean: [0.7343055078760488, 1.1723091291669543]
# After Teacher - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# After Learner - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# Population after Gen 45:
#
#  Generation 46
# Teaching factor T = 1
# Population mean: [0.7337811050861446, 1.1709178204869033]
# After Teacher - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# After Learner - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# Population after Gen 46:
#
#  Generation 47
# Teaching factor T = 2
# Population mean: [0.7488594350383799, 1.1647538167070022]
# After Teacher - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# After Learner - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# Population after Gen 47:
#
#  Generation 48
# Teaching factor T = 2
# Population mean: [0.7499052213571709, 1.1645600929899917]
# After Teacher - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# After Learner - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# Population after Gen 48:
#
#  Generation 49
# Teaching factor T = 2
# Population mean: [0.7586527710571143, 1.1754897409516796]
# After Teacher - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# After Learner - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# Population after Gen 49:
#
#  Generation 50
# Teaching factor T = 2
# Population mean: [0.7480857240403097, 1.1407696851620692]
# After Teacher - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# After Learner - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# Population after Gen 50:
#
#  Generation 51
# Teaching factor T = 2
# Population mean: [0.7535660868746236, 1.1337006676014045]
# After Teacher - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# After Learner - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# Population after Gen 51:
#
#  Generation 52
# Teaching factor T = 2
# Population mean: [0.7566292575240263, 1.1306478566735054]
# After Teacher - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# After Learner - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# Population after Gen 52:
#
#  Generation 53
# Teaching factor T = 1
# Population mean: [0.7663532498747065, 1.1253114979186631]
# After Teacher - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# After Learner - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# Population after Gen 53:
#
#  Generation 54
# Teaching factor T = 2
# Population mean: [0.7694205219087213, 1.1252445893506746]
# After Teacher - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# After Learner - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# Population after Gen 54:
#
#  Generation 55
# Teaching factor T = 1
# Population mean: [0.777953140263624, 1.1223035427057098]
# After Teacher - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# After Learner - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# Population after Gen 55:
#
#  Generation 56
# Teaching factor T = 1
# Population mean: [0.778156565514728, 1.0864968403770678]
# After Teacher - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# After Learner - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# Population after Gen 56:
#
#  Generation 57
# Teaching factor T = 1
# Population mean: [0.7879723213826035, 1.0986758098365417]
# After Teacher - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# After Learner - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# Population after Gen 57:
#
#  Generation 58
# Teaching factor T = 2
# Population mean: [0.7898801902527611, 1.0995761527157095]
# After Teacher - Best: [0.9979577755704009, 0.9967975980070732] (0.000081)
# After Learner - Best: [0.9951160423239335, 0.9900195844370964] (0.000029)
# Population after Gen 58:
#
#  Generation 59
# Teaching factor T = 1
# Population mean: [0.7924533977273213, 1.085102136538803]
# After Teacher - Best: [0.9951160423239335, 0.9900195844370964] (0.000029)
# After Learner - Best: [0.9951160423239335, 0.9900195844370964] (0.000029)
# Population after Gen 59:
#
#  Generation 60
# Teaching factor T = 1
# Population mean: [0.8078670592325085, 1.084276033888071]
# After Teacher - Best: [0.9951160423239335, 0.9900195844370964] (0.000029)
# After Learner - Best: [0.9951160423239335, 0.9900195844370964] (0.000029)
# Population after Gen 60:
#
#  Generation 61
# Teaching factor T = 2
# Population mean: [0.8132885119134151, 1.0841479084926686]
# After Teacher - Best: [0.9951160423239335, 0.9900195844370964] (0.000029)
# After Learner - Best: [0.9951160423239335, 0.9900195844370964] (0.000029)
# Population after Gen 61:
#
#  Generation 62
# Teaching factor T = 1
# Population mean: [0.8146425221456305, 1.0860889556263837]
# After Teacher - Best: [0.9951160423239335, 0.9900195844370964] (0.000029)
# After Learner - Best: [0.9951160423239335, 0.9900195844370964] (0.000029)
# Population after Gen 62:
#
#  Generation 63
# Teaching factor T = 1
# Population mean: [0.8249405041517633, 1.0845233676093224]
# After Teacher - Best: [0.9951160423239335, 0.9900195844370964] (0.000029)
# After Learner - Best: [0.9951160423239335, 0.9900195844370964] (0.000029)
# Population after Gen 63:
#
#  Generation 64
# Teaching factor T = 1
# Population mean: [0.8383361646897077, 1.0810448195520153]
# After Teacher - Best: [0.9951160423239335, 0.9900195844370964] (0.000029)
# After Learner - Best: [0.9951160423239335, 0.9900195844370964] (0.000029)
# Population after Gen 64:
#
#  Generation 65
# Teaching factor T = 2
# Population mean: [0.8442081256150942, 1.0685603838397282]
# After Teacher - Best: [0.9951160423239335, 0.9900195844370964] (0.000029)
# After Learner - Best: [0.9951160423239335, 0.9900195844370964] (0.000029)
# Population after Gen 65:
#
#  Generation 66
# Teaching factor T = 2
# Population mean: [0.8411528658007158, 1.0572280459313397]
# After Teacher - Best: [0.9951160423239335, 0.9900195844370964] (0.000029)
# After Learner - Best: [1.0007889228210485, 1.00126418955797] (0.000010)
# Population after Gen 66:
#
#  Generation 67
# Teaching factor T = 2
# Population mean: [0.8558906656172841, 1.0578373039237599]
# After Teacher - Best: [1.0007889228210485, 1.00126418955797] (0.000010)
# After Learner - Best: [1.0007889228210485, 1.00126418955797] (0.000010)
# Population after Gen 67:
#
#  Generation 68
# Teaching factor T = 2
# Population mean: [0.8564462252185094, 1.057317686947544]
# After Teacher - Best: [1.0007889228210485, 1.00126418955797] (0.000010)
# After Learner - Best: [1.0007889228210485, 1.00126418955797] (0.000010)
# Population after Gen 68:
#
#  Generation 69
# Teaching factor T = 2
# Population mean: [0.8566209339200204, 1.0569195816703378]
# After Teacher - Best: [1.0007889228210485, 1.00126418955797] (0.000010)
# After Learner - Best: [1.0007889228210485, 1.00126418955797] (0.000010)
# Population after Gen 69:
#
#  Generation 70
# Teaching factor T = 1
# Population mean: [0.8606395785642746, 1.058310463168282]
# After Teacher - Best: [1.0007889228210485, 1.00126418955797] (0.000010)
# After Learner - Best: [1.0007889228210485, 1.00126418955797] (0.000010)
# Population after Gen 70:
#
#  Generation 71
# Teaching factor T = 1
# Population mean: [0.8627099052279817, 1.0605954999222402]
# After Teacher - Best: [1.0007889228210485, 1.00126418955797] (0.000010)
# After Learner - Best: [1.0007889228210485, 1.00126418955797] (0.000010)
# Population after Gen 71:
#
#  Generation 72
# Teaching factor T = 2
# Population mean: [0.864153686495527, 1.061463459584437]
# After Teacher - Best: [1.0007889228210485, 1.00126418955797] (0.000010)
# After Learner - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# Population after Gen 72:
#
#  Generation 73
# Teaching factor T = 1
# Population mean: [0.8667623024201251, 1.0595920535999468]
# After Teacher - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# After Learner - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# Population after Gen 73:
#
#  Generation 74
# Teaching factor T = 2
# Population mean: [0.8663492148982159, 1.0554022818892783]
# After Teacher - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# After Learner - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# Population after Gen 74:
#
#  Generation 75
# Teaching factor T = 1
# Population mean: [0.8761679882137576, 1.044781814833878]
# After Teacher - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# After Learner - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# Population after Gen 75:
#
#  Generation 76
# Teaching factor T = 2
# Population mean: [0.8765568113340768, 1.044783417602243]
# After Teacher - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# After Learner - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# Population after Gen 76:
#
#  Generation 77
# Teaching factor T = 2
# Population mean: [0.8803013135880383, 1.0157271766222487]
# After Teacher - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# After Learner - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# Population after Gen 77:
#
#  Generation 78
# Teaching factor T = 2
# Population mean: [0.8783662882024638, 0.9960382253988257]
# After Teacher - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# After Learner - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# Population after Gen 78:
#
#  Generation 79
# Teaching factor T = 2
# Population mean: [0.8776858300266542, 0.9918934388522044]
# After Teacher - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# After Learner - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# Population after Gen 79:
#
#  Generation 80
# Teaching factor T = 1
# Population mean: [0.8840286089394712, 0.9889778825024126]
# After Teacher - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# After Learner - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# Population after Gen 80:
#
#  Generation 81
# Teaching factor T = 2
# Population mean: [0.8856613963790287, 0.9895981545467945]
# After Teacher - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# After Learner - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# Population after Gen 81:
#
#  Generation 82
# Teaching factor T = 2
# Population mean: [0.886178751484697, 0.9893187901320775]
# After Teacher - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# After Learner - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# Population after Gen 82:
#
#  Generation 83
# Teaching factor T = 1
# Population mean: [0.8866442771193442, 0.9899689856832632]
# After Teacher - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# After Learner - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# Population after Gen 83:
#
#  Generation 84
# Teaching factor T = 2
# Population mean: [0.8897625196864603, 0.9929382644035972]
# After Teacher - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# After Learner - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# Population after Gen 84:
#
#  Generation 85
# Teaching factor T = 1
# Population mean: [0.890399949646258, 0.9937935323875301]
# After Teacher - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# After Learner - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# Population after Gen 85:
#
#  Generation 86
# Teaching factor T = 2
# Population mean: [0.8933140666073589, 0.9975993079878981]
# After Teacher - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# After Learner - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# Population after Gen 86:
#
#  Generation 87
# Teaching factor T = 2
# Population mean: [0.895231676560585, 1.0010438089083413]
# After Teacher - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# After Learner - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# Population after Gen 87:
#
#  Generation 88
# Teaching factor T = 1
# Population mean: [0.8970929966792149, 1.0043753633172359]
# After Teacher - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# After Learner - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# Population after Gen 88:
#
#  Generation 89
# Teaching factor T = 2
# Population mean: [0.897402148675021, 1.0049895843652694]
# After Teacher - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# After Learner - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# Population after Gen 89:
#
#  Generation 90
# Teaching factor T = 1
# Population mean: [0.9076588543992697, 1.0066925497922528]
# After Teacher - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# After Learner - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# Population after Gen 90:
#
#  Generation 91
# Teaching factor T = 1
# Population mean: [0.9078160013609881, 1.0065011791349177]
# After Teacher - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# After Learner - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# Population after Gen 91:
#
#  Generation 92
# Teaching factor T = 1
# Population mean: [0.9077760028814639, 1.0057824803214823]
# After Teacher - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# After Learner - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# Population after Gen 92:
#
#  Generation 93
# Teaching factor T = 1
# Population mean: [0.9086987271056276, 1.0074658278839617]
# After Teacher - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# After Learner - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# Population after Gen 93:
#
#  Generation 94
# Teaching factor T = 1
# Population mean: [0.9093674275251292, 1.008471714061999]
# After Teacher - Best: [0.9996314490862623, 0.9993786287910836] (0.000001)
# After Learner - Best: [0.9999516706113764, 0.9999197933845445] (0.000000)
# Population after Gen 94:
#
#  Generation 95
# Teaching factor T = 1
# Population mean: [0.9093825400179498, 1.008311321174932]
# After Teacher - Best: [0.9999516706113764, 0.9999197933845445] (0.000000)
# After Learner - Best: [0.9999516706113764, 0.9999197933845445] (0.000000)
# Population after Gen 95:
#
#  Generation 96
# Teaching factor T = 2
# Population mean: [0.911474544757362, 1.0120535873244718]
# After Teacher - Best: [0.9999516706113764, 0.9999197933845445] (0.000000)
# After Learner - Best: [0.9999516706113764, 0.9999197933845445] (0.000000)
# Population after Gen 96:
#
#  Generation 97
# Teaching factor T = 1
# Population mean: [0.9115939783681055, 1.0122401067288056]
# After Teacher - Best: [0.9999516706113764, 0.9999197933845445] (0.000000)
# After Learner - Best: [0.9999516706113764, 0.9999197933845445] (0.000000)
# Population after Gen 97:
#
#  Generation 98
# Teaching factor T = 2
# Population mean: [0.9140382485799731, 1.0163037797871448]
# After Teacher - Best: [0.9999516706113764, 0.9999197933845445] (0.000000)
# After Learner - Best: [0.9999516706113764, 0.9999197933845445] (0.000000)
# Population after Gen 98:
#
#  Generation 99
# Teaching factor T = 2
# Population mean: [0.9151880307879813, 1.0184832075940016]
# After Teacher - Best: [0.9999516706113764, 0.9999197933845445] (0.000000)
# After Learner - Best: [0.9999516706113764, 0.9999197933845445] (0.000000)
# Population after Gen 99:
#
#  Generation 100
# Teaching factor T = 1
# Population mean: [0.925138781640306, 1.0197427966489825]
# After Teacher - Best: [0.9999516706113764, 0.9999197933845445] (0.000000)
# After Learner - Best: [0.9999516706113764, 0.9999197933845445] (0.000000)
# Population after Gen 100:
#
#  Final Result
# Best solution: [0.9999516706113764, 0.9999197933845445]
# Best fitness: 0.000000
# ([0.9999516706113764, 0.9999197933845445], 2.9395407551644008e-08)
